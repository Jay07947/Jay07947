# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

import matplotlib.font_manager as fm
import re
import collections
import numpy as np

text ="""루돌프 사슴코는 매우 반짝이는 코
만일 네가 봤다면 불붙는다 했겠지

다른 모든 사슴들 놀려대며 웃었네
가엾은 저 루돌프 외톨이가 되었네

안개낀 성탄절날 산타 말하길
루돌프가 밝으니 썰매를 끌어주렴

그 후론 사슴들이 그를 매우 사랑했네
루돌프 사슴코는 길이 길이 기억되리

루돌프 사슴코는 매우 반짝이는 코
만일 네가 봤다면 불붙는다 했겠지

다른 모든 사슴들 놀려대며 웃었네
가엾은 저 루돌프 외톨이가 되었네

안개낀 성탄절날 산타 말하길
루돌프가 밝으니 썰매를 끌어주렴

그 후론 사슴들이 그를 매우 사랑했네
루돌프 사슴코는 길이 길이 기억되리
길이 길이 기억되리"""

spwords = set(STOPWORDS)
spwords.add('네가')


wc1 = WordCloud(max_font_size=200, stopwords=spwords, font_path='c:/windows/fonts/H2HDRM.TTF',
               background_color='white', width=800, height=800)
wc1.generate(text)


def grey_color_func(word, font_size, position,orientation,random_state=None, **kwargs):
       return("hsl(5,100%%, %d%%)" % np.random.randint(30,80))

#change the color setting
# wc1.recolor(color_func = grey_color_func)
# wc1.recolor(color_func = grey_color_func)


plt.figure(figsize=(10,8))
plt.imshow(wc1)
plt.tight_layout(pad=0)
plt.axis('off')
plt.show()
