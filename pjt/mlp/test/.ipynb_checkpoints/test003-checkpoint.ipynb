# %%
def read_data(filename):
    with open(filename, 'r', encoding='UTF8') as f:
        data = [line.split('\t') for line in f.read().splitlines()]
        # txt 파일의 헤더(id document label)는 제외하기
        data = data[1:]
    return data

# %%
import requests 
from bs4 import BeautifulSoup 
import pandas  
from tqdm import tqdm

def get_review(pageNo):
    result = []

    url = 'https://movie.naver.com/movie/point/af/list.nhn?&page={}'.format(pageNo)
    response = requests.get(url) 

    soup = BeautifulSoup(response.text, 'lxml') 
    trs = soup.select("table.list_netizen > tbody > tr")
    #soup.select('상위태그명 > 하위태그명 > 하위태그명')
    
    
    for tr in trs:
        tds = tr.select('td')
        number = tds[0].text 
        title = tds[1].select_one('a').text 
        star = tds[1].select_one('em').text 
        content = tds[1].text[len(title) +17 : -3].strip() 

        result.append([star, content]) 
        
    return result

def get_reviews(start = 1, end = 50): 
    if start < 1:
        start = 1
    if end > 1000:
        end = 1000

    result = []
    for i in tqdm(range(start, end+1)):
        result.extend(get_review(i))
    return result



if __name__ == '__main__':
    reviewData = get_reviews(1, 100)

    ##엑셀파일
    col = ['별점', '내용']
    dataFrame = pandas.DataFrame(reviewData, columns= col)
    dataList = dataFrame.values.tolist()
    print(dataList)
#     dataFrame.to_excel("Movie_data.xlsx", 
#                        sheet_name= '네이버 영화 네티즌 리뷰', 
#                        header=True, 
#                        startrow=0, encoding='UTF-8')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:12<00:00,  8.23it/s]
# ...

# %%
import json
import os
from pprint import pprint
from konlpy.tag import Okt

okt = Okt()

def tokenize(doc):
    # norm은 정규화, stem은 근어로 표시하기를 나타냄
    return ['/'.join(t) for t in okt.pos(doc, norm=True, stem=True)]

# if os.path.isfile('movie_docs.json'):
#     with open('movie_docs.json', encoding="utf-8") as f:
#         movie_docs = json.load(f)
# else:

movie_docs = [(tokenize(row[1]), row[0]) for row in dataList]
# JSON 파일로 저장
with open('movie_docs.json', 'w', encoding="utf-8") as make_file:
    json.dump(movie_docs, make_file, ensure_ascii=False, indent="\t")


# 예쁘게(?) 출력하기 위해서 pprint 라이브러리 사용
pprint(len(dataList))
pprint(len(dataList[0]))
pprint(movie_docs[1])
print(type(movie_docs))

list1 = []
list2 = []
list3 = []
list4 = []
list5 = []
list6 = []
list7 = []
list8 = []
list9 = []
list10 = []

for i in movie_docs :
    
    if int(i[1])==1 :
       list1.append(i)
    elif int(i[1])==2 :
       list2.append(i)
    elif int(i[1])==3 :
       list3.append(i)
    elif int(i[1])==4 :
       list4.append(i)
    elif int(i[1])==5 :
       list5.append(i)
    elif int(i[1])==6 :
       list6.append(i)
    elif int(i[1])==7 :
       list7.append(i)
    elif int(i[1])==8 :
       list8.append(i)
    elif int(i[1])==9 :
       list9.append(i)
    else :
       list10.append(i)
# Out:
# 1000
# 2
# (['원작/Noun',
#   '가/Josa',
#   '다른/Noun',
#   '내용/Noun',
#   '이라고/Josa',
#   '하다/Verb',
#   '기대하다/Adjective',
#   '크게/Noun',
#   '다른/Modifier',
#   '점/Noun',
#   '이/Josa',
#   '없다/Adjective',
#   '너무/Adverb',
#   '기대하다/Adjective',
#   '실망/Noun',
#   '이/Josa',
#   '조금/Noun',
#   '있다/Adjective',
#   '한지민/Noun',
#   '과/Josa',
#   '남주혁/Noun',
#   '배우/Noun',
#   '님/Suffix',
#   '의/Josa',
#   '연기력/Noun',
#   '에는/Josa',
#   '문제/Noun',
#   '가/Josa',
#   '없다/Adjective',
#   '스토리/Noun',
#   '생략/Noun',
#   '이/Josa',
#   '조금/Noun',
#   '있다/Adjective'],
#  '8')
# <class 'list'>

# %%
tokens1 = [t for d in list1 for t in d[0]]
tokens2 = [t for d in list2 for t in d[0]]
tokens3 = [t for d in list3 for t in d[0]]
tokens4 = [t for d in list4 for t in d[0]]
tokens5 = [t for d in list5 for t in d[0]]
tokens6 = [t for d in list6 for t in d[0]]
tokens7 = [t for d in list7 for t in d[0]]
tokens8 = [t for d in list8 for t in d[0]]
tokens9 = [t for d in list9 for t in d[0]]
tokens10 = [t for d in list10 for t in d[0]]

tokens = [t for d in movie_docs for t in d[0]]
print(len(tokens10))
print(tokens10[0])
# Out:
# 7927
# 천우희/Noun

# %%
import nltk
# text1 = nltk.Text(tokens1, name='NMSC')
# text2 = nltk.Text(tokens2, name='NMSC')
# text3 = nltk.Text(tokens3, name='NMSC')
# text4 = nltk.Text(tokens4, name='NMSC')
# text5 = nltk.Text(tokens5, name='NMSC')
# text6 = nltk.Text(tokens6, name='NMSC')
# text7 = nltk.Text(tokens7, name='NMSC')
# text8 = nltk.Text(tokens8, name='NMSC')
# text9 = nltk.Text(tokens9, name='NMSC')
# text10 = nltk.Text(tokens10, name='NMSC')

text = nltk.Text(tokens, name='NMSC')

# print(len(set(text1.tokens)))
# print(len(set(text2.tokens)))
# print(len(set(text3.tokens)))
# print(len(set(text4.tokens)))
# print(len(set(text5.tokens)))
# print(len(set(text6.tokens)))
# print(len(set(text7.tokens)))
# print(len(set(text8.tokens)))
# print(len(set(text9.tokens)))
# print(len(set(text10.tokens)))

# # 출현 빈도가 높은 상위 토큰 20개
# result = []

# for i in range(1,29) :
#     result.append([text1.vocab().most_common(30)[i], 1]) 
#     result.append([text2.vocab().most_common(30)[i], 2])
#  #   result.append([text3.vocab().most_common(30)[i], 3]) 
#     result.append([text4.vocab().most_common(30)[i], 4]) 
#     result.append([text5.vocab().most_common(30)[i], 5]) 
#     result.append([text6.vocab().most_common(30)[i], 6]) 
#     result.append([text7.vocab().most_common(30)[i], 7]) 
#     result.append([text8.vocab().most_common(30)[i], 8]) 
#     result.append([text9.vocab().most_common(30)[i], 9]) 
#     result.append([text10.vocab().most_common(30)[i], 10]) 

# print(type(result))
# ##엑셀파일
# import pandas as pd

# df = pd.DataFrame(result)
# df.to_csv("word_data4.csv",  header=True, index = False, encoding='utf-8-sig')

# %%
import requests 
from bs4 import BeautifulSoup 
import pandas as pd
from tqdm import tqdm

song_data = pd.read_csv('계절노래.csv')
print(len(song_data))
print(type(song_data))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-6-aba1b12a2e08> in <module>
#       4 from tqdm import tqdm
#       5
# ----> 6 song_data = pd.read_csv('계절노래.csv')
#       7 print(len(song_data))
#       8 print(type(song_data))
#
# ...

# %%
# 자주 사용되는 토큰 10000개를 사용해서 데이터를 벡터화
# 문서 집합에서 단어 토큰을 생성하고 각 단어의 수를 세어 BOW(Bag of Words) 인코딩한 벡터를 만드는 역할
# 시간이 꽤 걸립니다! 시간을 절약하고 싶으면 most_common의 매개변수를 줄여보세요.

selected_words = [f[0] for f in text.vocab().most_common(5000)]

def term_frequency(doc):
    return [doc.count(word) for word in selected_words]

train_docs = movie_docs[:800]
test_docs = movie_docs[801:]

train_x = [term_frequency(d) for d, _ in train_docs]
test_x = [term_frequency(d) for d, _ in test_docs]
train_y = [c for _, c in train_docs]
test_y = [c for _, c in test_docs]

# %%
#데이터를 float로 형 변환
import numpy as np

x_train = np.asarray(train_x).astype('float32')
x_test = np.asarray(test_x).astype('float32')

y_train = np.asarray(train_y).astype('float32')
y_test = np.asarray(test_y).astype('float32')

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(None, 1965)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer=optimizers.RMSprop(lr=0.001),
             loss=losses.binary_crossentropy,
             metrics=[metrics.binary_accuracy])

model.fit(x_train, y_train, epochs=10, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-e5a401ceb608> in <module>
#      14              metrics=[metrics.binary_accuracy])
#      15
# ---> 16 model.fit(x_train, y_train, epochs=10, batch_size=512)
#      17 results = model.evaluate(x_test, y_test)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ...

# %%
results
# Out:
# [-20.712257385253906, 0.08080808073282242]

# %%
def predict_pos_neg(review):
    token = tokenize(review)
    tf = term_frequency(token)
    data = np.expand_dims(np.asarray(tf).astype('float32'), axis=0)
    score = float(model.predict(data))
    print("[{}]는 {:.2f}% 확률로 별점을 [{}]점을 준 리뷰이지 않을까 추측해봅니다.^^\n".format(review, score * 100,data))
#     if(score > 0.5):
#         print("[{}]는 {:.2f}% 확률로 긍정 리뷰이지 않을까 추측해봅니다.^^\n".format(review, score * 100))
#     else:
#         print("[{}]는 {:.2f}% 확률로 부정 리뷰이지 않을까 추측해봅니다.^^;\n".format(review, (1 - score) * 100))

# %%
predict_pos_neg("올해 최고의 영화! 세 번 넘게 봐도 질리지가 않네요.")
predict_pos_neg("배경 음악이 영화의 분위기랑 너무 안 맞았습니다. 몰입에 방해가 됩니다.")
predict_pos_neg("주연 배우가 신인인데 연기를 진짜 잘 하네요. 몰입감 ㅎㄷㄷ")
predict_pos_neg("믿고 보는 감독이지만 이번에는 아니네요")
predict_pos_neg("주연배우 때문에 봤어요")
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, None, 1965) for input Tensor("dense_6_input:0", shape=(None, None, 1965), dtype=float32), but it was called on an input with incompatible shape (None, 1965).
# [올해 최고의 영화! 세 번 넘게 봐도 질리지가 않네요.]는 91.44% 확률로 별점을 [[[1. 0. 0. ... 0. 0. 0.]]]점을 준 리뷰이지 않을까 추측해봅니다.^^
#
# [배경 음악이 영화의 분위기랑 너무 안 맞았습니다. 몰입에 방해가 됩니다.]는 96.62% 확률로 별점을 [[[2. 0. 1. ... 0. 0. 0.]]]점을 준 리뷰이지 않을까 추측해봅니다.^^
#
# [주연 배우가 신인인데 연기를 진짜 잘 하네요. 몰입감 ㅎㄷㄷ]는 95.10% 확률로 별점을 [[[1. 1. 0. ... 0. 0. 0.]]]점을 준 리뷰이지 않을까 추측해봅니다.^^
#
# [믿고 보는 감독이지만 이번에는 아니네요]는 86.21% 확률로 별점을 [[[0. 0. 0. ... 0. 0. 0.]]]점을 준 리뷰이지 않을까 추측해봅니다.^^
#
# [주연배우 때문에 봤어요]는 79.51% 확률로 별점을 [[[0. 0. 0. ... 0. 0. 0.]]]점을 준 리뷰이지 않을까 추측해봅니다.^^

# %%
predict_pos_neg("강동원")
predict_pos_neg("헐")
predict_pos_neg("수지 너무 예뻐요")
# Out:
# [강동원]는 53.20% 확률로 긍정 리뷰이지 않을까 추측해봅니다.^^
#
# [헐]는 94.68% 확률로 부정 리뷰이지 않을까 추측해봅니다.^^;
#
# [수지 너무 예뻐요]는 89.81% 확률로 긍정 리뷰이지 않을까 추측해봅니다.^^
